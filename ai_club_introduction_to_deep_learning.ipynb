# %%
# !pip install torch torchvision torchaudio
# !pip install datasets
# !pip install scikit-learn
# !pip install torcheval
# !pip install matplotlib
# !pip install numpy
# Out:
# Requirement already satisfied: torch in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (2.10.0)
# Requirement already satisfied: torchvision in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (0.25.0)
# Requirement already satisfied: torchaudio in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (2.10.0)
# Requirement already satisfied: filelock in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from torch) (3.20.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from torch) (80.10.2)
# Requirement already satisfied: sympy>=1.13.3 in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from torch) (2025.10.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from torch) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from torch) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from torch) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from torch) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from torch) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from torch) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from torch) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from torch) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from torch) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from torch) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from torch) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from torch) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from cuda-bindings==12.9.4->torch) (1.3.4)
# Requirement already satisfied: numpy in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from torchvision) (2.4.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from torchvision) (12.1.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: datasets in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (4.5.0)
# Requirement already satisfied: filelock in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from datasets) (3.20.3)
# Requirement already satisfied: numpy>=1.17 in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from datasets) (2.4.2)
# Requirement already satisfied: pyarrow>=21.0.0 in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from datasets) (23.0.1)
# Requirement already satisfied: dill<0.4.1,>=0.3.0 in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from datasets) (0.4.0)
# Requirement already satisfied: pandas in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from datasets) (3.0.0)
# Requirement already satisfied: requests>=2.32.2 in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from datasets) (2.32.5)
# Requirement already satisfied: httpx<1.0.0 in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from datasets) (0.28.1)
# Requirement already satisfied: tqdm>=4.66.3 in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from datasets) (4.67.3)
# Requirement already satisfied: xxhash in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.19 in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from datasets) (0.70.18)
# Requirement already satisfied: fsspec<=2025.10.0,>=2023.1.0 in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (2025.10.0)
# Requirement already satisfied: huggingface-hub<2.0,>=0.25.0 in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from datasets) (1.4.1)
# Requirement already satisfied: packaging in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from datasets) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from datasets) (6.0.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (3.13.3)
# Requirement already satisfied: anyio in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from httpx<1.0.0->datasets) (4.12.1)
# Requirement already satisfied: certifi in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from httpx<1.0.0->datasets) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from httpx<1.0.0->datasets) (1.0.9)
# Requirement already satisfied: idna in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from httpx<1.0.0->datasets) (3.11)
# Requirement already satisfied: h11>=0.16 in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from httpcore==1.*->httpx<1.0.0->datasets) (0.16.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (1.2.0)
# Requirement already satisfied: shellingham in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (1.5.4)
# Requirement already satisfied: typer-slim in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (0.24.0)
# Requirement already satisfied: typing-extensions>=4.1.0 in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (4.15.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.22.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from requests>=2.32.2->datasets) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from requests>=2.32.2->datasets) (2.6.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Requirement already satisfied: typer>=0.24.0 in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from typer-slim->huggingface-hub<2.0,>=0.25.0->datasets) (0.24.0)
# Requirement already satisfied: click>=8.2.1 in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from typer>=0.24.0->typer-slim->huggingface-hub<2.0,>=0.25.0->datasets) (8.3.1)
# Requirement already satisfied: rich>=12.3.0 in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from typer>=0.24.0->typer-slim->huggingface-hub<2.0,>=0.25.0->datasets) (14.3.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from typer>=0.24.0->typer-slim->huggingface-hub<2.0,>=0.25.0->datasets) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from rich>=12.3.0->typer>=0.24.0->typer-slim->huggingface-hub<2.0,>=0.25.0->datasets) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from rich>=12.3.0->typer>=0.24.0->typer-slim->huggingface-hub<2.0,>=0.25.0->datasets) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer>=0.24.0->typer-slim->huggingface-hub<2.0,>=0.25.0->datasets) (0.1.2)
# Requirement already satisfied: scikit-learn in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (1.8.0)
# Requirement already satisfied: numpy>=1.24.1 in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from scikit-learn) (2.4.2)
# Requirement already satisfied: scipy>=1.10.0 in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from scikit-learn) (1.17.0)
# Requirement already satisfied: joblib>=1.3.0 in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: torcheval in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (0.0.7)
# Requirement already satisfied: typing-extensions in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from torcheval) (4.15.0)
# Requirement already satisfied: matplotlib in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from matplotlib) (2.4.2)
# Requirement already satisfied: packaging>=20.0 in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from matplotlib) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: numpy in /home/suggus/miniconda3/envs/deep_learning/lib/python3.12/site-packages (2.4.2)

# %%
import torch
import numpy as np

import matplotlib
import matplotlib.pyplot as plt
import torch.nn.functional as F

from torch import nn
from datasets import load_dataset
from torchvision import transforms
from torch.utils.data import DataLoader, Subset
from sklearn.model_selection import train_test_split
from torcheval.metrics.functional import (
    multiclass_accuracy,
    multiclass_f1_score
)

# %%
dt_train = load_dataset("ylecun/mnist", split="train")
dt_test = load_dataset("ylecun/mnist", split="test")
dt_train, dt_test
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# (Dataset({
#      features: ['image', 'label'],
#      num_rows: 60000
#  }),
#  Dataset({
#      features: ['image', 'label'],
#      num_rows: 10000
#  }))

# %%
# Convert PIL Image to Tensor
transform = transforms.ToTensor()

def transform_to_torch(batch):
    batch["image"] = [transform(img) for img in batch["image"]]
    return batch

dt_train_torch = dt_train.with_transform(transform_to_torch)
dt_test_torch = dt_test.with_transform(transform_to_torch)
dt_train_torch, dt_test_torch
# Out:
# (Dataset({
#      features: ['image', 'label'],
#      num_rows: 60000
#  }),
#  Dataset({
#      features: ['image', 'label'],
#      num_rows: 10000
#  }))

# %%
train_indices, valid_indices = train_test_split(
    range(len(dt_train_torch)),
    test_size=0.2,
    random_state=42,
    stratify=dt_train['label']
)

train_subset = Subset(dt_train_torch, train_indices)
valid_subset = Subset(dt_train_torch, valid_indices)

batch_size = 128
train_dl = DataLoader(train_subset, batch_size=batch_size, shuffle=True)
valid_dl = DataLoader(valid_subset, batch_size=batch_size, shuffle=False)
test_dl = DataLoader(dt_test_torch, batch_size=batch_size, shuffle=False)

# %%
len(train_dl), len(valid_dl), len(test_dl)
# Out:
# (375, 94, 79)

# %%
sample = dt_train_torch[0]

print(sample["image"].shape)   # torch.Size([1, 28, 28]) (C, H, W)
print(sample["label"])
# Out:
# torch.Size([1, 28, 28])
# 5

# %%
plt.figure()
plt.title(sample["label"])
plt.imshow(sample["image"].permute(1, 2, 0), cmap="gray") # (H, W, C)
plt.show()

# %%
plt.figure(figsize=(15, 4))

for i in range(10):
    sample = dt_train_torch[i]
    plt.subplot(2, 5, i + 1)
    plt.imshow(sample['image'].permute(1, 2, 0), cmap='gray')
    plt.title(f"Label: {sample['label']}")
    plt.axis('off')

plt.tight_layout()
plt.show()

# %%
device = None
if torch.cuda.is_available():
    device = torch.device("cuda")
elif torch.backends.mps.is_available():
    device = torch.device("mps")
else:
    device = torch.device("cpu")
device
# Out:
# device(type='cuda')

# %%
# Our Image size = 28 * 28 * 1 (Height, Width, Channel)
# We will use ReLu as our activation function
# You can try different activation functions (LeakyReLU, ELU, Tanh)
class AIC_Net(nn.Module):
    def __init__(self):
        super().__init__()
        self.flatten = nn.Flatten() # Convert image to vector
        self.l1 = nn.Linear(28*28*1, 256)
        self.l2 = nn.Linear(256, 64)
        self.l3 = nn.Linear(64, 10)
    def forward(self, x):
        x = self.flatten(x)
        o1 = F.relu(self.l1(x)) # Activation Function
        o2 = F.relu(self.l2(o1))
        logits = self.l3(o2)
        return logits

model = AIC_Net().to(device)
model
# Out:
# AIC_Net(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (l1): Linear(in_features=784, out_features=256, bias=True)
#   (l2): Linear(in_features=256, out_features=64, bias=True)
#   (l3): Linear(in_features=64, out_features=10, bias=True)
# )

# %%
for batch in train_dl:
    imgs, lbls = batch['image'], batch['label']
    break
preds = model(imgs.to(device))
preds.shape
# Out:
# torch.Size([128, 10])

# %%
loss_fn = nn.CrossEntropyLoss()

# %%
for x in model.parameters():
    print(x.shape)
# Out:
# torch.Size([256, 784])
# torch.Size([256])
# torch.Size([64, 256])
# torch.Size([64])
# torch.Size([10, 64])
# torch.Size([10])

# %%
def train_one_epoch(dataloader, model, loss_fn, optimizer, epoch, log_step_interval=50):
    # Size of the dataset
    size = len(dataloader.dataset)

    # Training mode
    model.train()

    # Keep track of the loss
    running_loss = 0.
    last_loss = 0.

    # We use enumerate to track the batch index
    for i, batch in enumerate(dataloader):
        X, y = batch['image'], batch['label']
        X, y = X.to(device), y.to(device)

        # zero the parameter gradients
        optimizer.zero_grad()

        # Prediction (i.e., forward)
        pred = model(X)

        # Compute loss
        loss = loss_fn(pred, y)

        # Backpropagation
        loss.backward()  # calculate the backward gradients
        optimizer.step()  # adjust model's weights based on the observed gradients

        # Keep track of the loss
        running_loss += loss.item()
        if (i+1) % log_step_interval == 0:
            last_loss = running_loss / log_step_interval
            current = (i + 1) * len(X)
            print(f"loss: {last_loss:>7f}  [{current:>5d}/{size:>5d}]")
            running_loss = 0.

# %%
def test(dataloader, model, loss_fn):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)

    # Test mode
    model.eval()

    # Predict on test set
    loss, correct = 0, 0
    y_preds, y_trues = [], []
    with torch.no_grad():
        for batch in dataloader:
            X, y = batch['image'], batch['label']
            X, y = X.to(device), y.to(device)
            # Prediction
            pred = model(X)
            y_pred = pred.argmax(1)
            # Compute loss
            loss += loss_fn(pred, y).item()
            # Performance metrics
            y_preds.append(y_pred)
            y_trues.append(y)
    y_preds = torch.cat(y_preds)
    y_trues = torch.cat(y_trues)

    # Average loss
    loss /= num_batches

    y_preds = y_preds.cpu()
    y_trues = y_trues.cpu()
    # Performance metrics
    perf = {
        'accuracy': multiclass_accuracy(y_preds, y_trues),
        'f1': multiclass_f1_score(y_preds, y_trues),
    }

    return loss, perf

# %%
# Specify optimizer and Choose optimal Learning Rate for our model
# e.g., SGD, Adam, AdamW, RMSProp, etc.
# 1e-3 = 0.001, 1e-4 = 0.0001, 1e-5 = 0.00001
#optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
#optimizer = torch.optim.AdamW(model.parameters(), lr=1e-3)
#optimizer = torch.optim.RMSProp(model.parameters(), lr=1e-3)
# Try to find the sweet spot for optimizer and Learning rate
optimizer = torch.optim.SGD(model.parameters(), lr=1e-3)

# Too much epochs can lead to overfitting
epochs = 10
best_vloss = 100000.
hist = {
    'train_loss': [],
    'train_acc': [],
    'val_loss': [],
    'val_acc': [],
}
for epoch in range(epochs):
    print(f"Epoch {epoch+1}\n-------------------------------")
    train_one_epoch(train_dl, model, loss_fn, optimizer, epoch)
    train_loss, train_perf = test(train_dl, model, loss_fn)
    val_loss, val_perf = test(valid_dl, model, loss_fn)

    # History for learning curve
    hist['train_loss'].append(train_loss)
    hist['val_loss'].append(val_loss)
    hist['train_acc'].append(train_perf['accuracy'])
    hist['val_acc'].append(val_perf['accuracy'])

    # Track best performance, and save the model's state
    if val_loss < best_vloss:
        best_vloss = val_loss
        torch.save(model.state_dict(), 'model_best_vloss.pth')
        print('Saved best model to model_best_vloss.pth')
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# loss: 2.302725  [ 6400/48000]
# loss: 2.298649  [12800/48000]
# loss: 2.298262  [19200/48000]
# loss: 2.295519  [25600/48000]
# loss: 2.294420  [32000/48000]
# loss: 2.293921  [38400/48000]
# loss: 2.292393  [44800/48000]
# Saved best model to model_best_vloss.pth
# Epoch 2
# -------------------------------
# loss: 2.289195  [ 6400/48000]
# loss: 2.287248  [12800/48000]
# loss: 2.285238  [19200/48000]
# loss: 2.284586  [25600/48000]
# loss: 2.281898  [32000/48000]
# loss: 2.280226  [38400/48000]
# loss: 2.277899  [44800/48000]
# Saved best model to model_best_vloss.pth
# Epoch 3
# -------------------------------
# loss: 2.275079  [ 6400/48000]
# loss: 2.272738  [12800/48000]
# loss: 2.271103  [19200/48000]
# loss: 2.268778  [25600/48000]
# loss: 2.268282  [32000/48000]
# loss: 2.264758  [38400/48000]
# loss: 2.261893  [44800/48000]
# Saved best model to model_best_vloss.pth
# Epoch 4
# -------------------------------
# loss: 2.257869  [ 6400/48000]
# loss: 2.255838  [12800/48000]
# loss: 2.254011  [19200/48000]
# loss: 2.251305  [25600/48000]
# loss: 2.249808  [32000/48000]
# loss: 2.246145  [38400/48000]
# loss: 2.244454  [44800/48000]
# Saved best model to model_best_vloss.pth
# Epoch 5
# -------------------------------
# loss: 2.239529  [ 6400/48000]
# loss: 2.236199  [12800/48000]
# loss: 2.234539  [19200/48000]
# loss: 2.228237  [25600/48000]
# loss: 2.226574  [32000/48000]
# loss: 2.222430  [38400/48000]
# loss: 2.221825  [44800/48000]
# Saved best model to model_best_vloss.pth
# Epoch 6
# -------------------------------
# loss: 2.216292  [ 6400/48000]
# loss: 2.210743  [12800/48000]
# loss: 2.206933  [19200/48000]
# loss: 2.203883  [25600/48000]
# loss: 2.199479  [32000/48000]
# loss: 2.197101  [38400/48000]
# loss: 2.192002  [44800/48000]
# Saved best model to model_best_vloss.pth
# Epoch 7
# -------------------------------
# loss: 2.184984  [ 6400/48000]
# loss: 2.182170  [12800/48000]
# loss: 2.175536  [19200/48000]
# loss: 2.174234  [25600/48000]
# loss: 2.167775  [32000/48000]
# loss: 2.162437  [38400/48000]
# loss: 2.157805  [44800/48000]
# Saved best model to model_best_vloss.pth
# Epoch 8
# -------------------------------
# loss: 2.148324  [ 6400/48000]
# loss: 2.142284  [12800/48000]
# loss: 2.135919  [19200/48000]
# loss: 2.133486  [25600/48000]
# loss: 2.129415  [32000/48000]
# loss: 2.121978  [38400/48000]
# loss: 2.116460  [44800/48000]
# Saved best model to model_best_vloss.pth
# Epoch 9
# -------------------------------
# loss: 2.109629  [ 6400/48000]
# loss: 2.099188  [12800/48000]
# loss: 2.091953  [19200/48000]
# loss: 2.086061  [25600/48000]
# loss: 2.083191  [32000/48000]
# loss: 2.074362  [38400/48000]
# loss: 2.062057  [44800/48000]
# Saved best model to model_best_vloss.pth
# Epoch 10
# -------------------------------
# loss: 2.047775  [ 6400/48000]
# loss: 2.047167  [12800/48000]
# loss: 2.039679  [19200/48000]
# loss: 2.037413  [25600/48000]
# loss: 2.022511  [32000/48000]
# loss: 2.013220  [38400/48000]
# loss: 2.006769  [44800/48000]
# Saved best model to model_best_vloss.pth
# Done!

# %%
fig, ax = plt.subplots(figsize=(8,6))
ax.plot(hist['train_loss'], label='train')
ax.plot(hist['val_loss'], label='valid')
ax.set_ylabel('Loss')
ax.set_xlabel('Epochs')
plt.legend()
plt.show()

fig, ax = plt.subplots(figsize=(8,6))
ax.plot(hist['train_acc'], label='train')
ax.plot(hist['val_acc'], label='valid')
ax.set_ylabel('Accuracy')
ax.set_xlabel('Epochs')
plt.legend()
plt.show()

plt.close('all')

# %%
model_best = AIC_Net().to(device)
model_best.load_state_dict(torch.load("model_best_vloss.pth"))
# Out:
# <All keys matched successfully>

# %%
model_best.eval()

# Get one batch of data
for batch in test_dl:
    imgs, lbls = batch['image'], batch['label']
    break

X, y = imgs[0:1].to(device), lbls[0:1].to(device)
with torch.no_grad():
    pred = model_best(X)
    predicted, actual = pred[0].argmax(0), y.cpu().item()

plt.figure()
plt.title(f"Predicted: {predicted}, Actual: {actual}")
plt.imshow(imgs[0].permute(1, 2, 0), cmap='gray')
plt.show()

# %%
# Use the best model on the validation set
test_loss, test_perf = test(test_dl, model_best, loss_fn)
print(f"Test: loss={test_loss:>8f}, acc={(100*test_perf['accuracy']):>0.1f}%, f1={(100*test_perf['f1']):>0.1f}%")
# Out:
# Test: loss=1.993077, acc=58.9%, f1=58.9%

# %% [markdown]
# **Challenge**
#
# 1. Can you try to improve the model accuracy?
#
# 2. Try different architectures:
#     - Shallow: [784 → 128 → 10]
#     - Deep: [784 → 512 → 256 → 128 → 64 → 10]
#     - Funnel: [784 → 512 → 256 → 128 → 10]
#     - Wide: [784 → 1024 → 512 → 10]
#
#     Does increasing the depth or size of a neural network always lead to better performance?
