# %% [markdown]
# # Lab 6: Deep Learning with Keras for Regression
# ## Regression with Keras: California Housing Dataset
# This notebook demonstrates how to perform regression using Keras on the California Housing dataset, including data visualization, model building, training, and evaluation.

# %%
# Import necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import seaborn as sns
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import MeanSquaredError

# %% [markdown]
# ## Load and Explore the Dataset
# We load the California Housing dataset, which includes features like median income and house age, and the target is the median house value.
#
# About this dataset
# 1. MedInc: Median income
# 2. HouseAge: Median house age
# 3. AveRooms: Average number of rooms for houses within a block
# 4. AveBedrms: Average number of bedrooms for houses within a block
# 5. Population: Total number of people residing within a block
# 6. AveOccup: Average number of people residing in each household
# 7. Latitude: A measure of how far north a house is; a higher value is farther north
# 8. Longitude: A measure of how far west a house is; a higher value is farther west
# 9. MedHouseVal: Median house value for households within a block (measured in US Dollars)
#
# Note. 9. is the target

# %%
# Load the dataset to a pandas dataframe(df)

# -------------------------------
# Your code here
# -------------------------------
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  Target
# 0    -122.23   4.526
# 1    -122.22   3.585
# 2    -122.24   3.521
# 3    -122.25   3.413
# 4    -122.25   3.422

# %% [markdown]
# ## Visualize the Dataset
# Let us plot some features against the target to understand their relationship.

# %%
# Plot feature vs target
sns.pairplot(df, corner=True)

# %% [markdown]
# ## Split and Scale the Dataset
# We split the dataset into training and testing sets and scale the features to ensure the model trains effectively.

# %%
# Split the data using train_test_split function
# Use 20% of the data for testing and the rest for training
# Use random_state=42

# -------------------------------
# Your code here
# -------------------------------


# Scale the data
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ## Build the Model
# We define a Sequential model with two hidden layers and a single output neuron for regression.

# %%
# Define the model
# Complete the code to build a Sequential model
# The model should have 3 layers with 64, 32 and 1 neuron respectively
# Use 'relu' activation function for the first two layers and no activation function for the last layer

model = Sequential([
    Dense(..., activation=..., input_dim=...),
    Dense(..., activation=...),
    Dense(...)  # Single output for regression
])

# %%
# Compile the model
# Use Adam optimizer with learning rate 0.001 and MeanSquaredError as the loss function

# -------------------------------
# Your code here
# -------------------------------

# %% [markdown]
# ## Train the Model
# We train the model for 50 epochs, validating on the test data.

# %%
# Train the model
# Use 50 epochs and batch size of 32
# Use the test data as the validation data
# return the training history(history)

# -------------------------------
# Your code here
# -------------------------------
# Out:
# Epoch 1/50
# 516/516 [==============================] - 1s 942us/step - loss: 0.7765 - mae: 0.5861 - val_loss: 0.4910 - val_mae: 0.5218
# Epoch 2/50
# 516/516 [==============================] - 0s 796us/step - loss: 0.5187 - mae: 0.4519 - val_loss: 0.3847 - val_mae: 0.4384
# Epoch 3/50
# 516/516 [==============================] - 0s 835us/step - loss: 0.3801 - mae: 0.4317 - val_loss: 0.3660 - val_mae: 0.4320
# Epoch 4/50
# 516/516 [==============================] - 0s 790us/step - loss: 0.3538 - mae: 0.4197 - val_loss: 0.3567 - val_mae: 0.4250
# Epoch 5/50
# 516/516 [==============================] - 0s 796us/step - loss: 0.3422 - mae: 0.4115 - val_loss: 0.3450 - val_mae: 0.4172
# Epoch 6/50
# 516/516 [==============================] - 0s 802us/step - loss: 0.3314 - mae: 0.4042 - val_loss: 0.3434 - val_mae: 0.4136
# Epoch 7/50
# 516/516 [==============================] - 0s 806us/step - loss: 0.3249 - mae: 0.3983 - val_loss: 0.3513 - val_mae: 0.4336
# Epoch 8/50
# 516/516 [==============================] - 0s 796us/step - loss: 0.3452 - mae: 0.3970 - val_loss: 0.3276 - val_mae: 0.3937
# Epoch 9/50
# 516/516 [==============================] - 0s 800us/step - loss: 0.3212 - mae: 0.3902 - val_loss: 0.3149 - val_mae: 0.3905
# Epoch 10/50
# 516/516 [==============================] - 0s 808us/step - loss: 0.3095 - mae: 0.3870 - val_loss: 0.3188 - val_mae: 0.3847
# Epoch 11/50
# 516/516 [==============================] - 0s 825us/step - loss: 0.3154 - mae: 0.3845 - val_loss: 0.3107 - val_mae: 0.3787
# Epoch 12/50
# 516/516 [==============================] - 0s 818us/step - loss: 0.3027 - mae: 0.3803 - val_loss: 0.3086 - val_mae: 0.3793
# Epoch 13/50
# 516/516 [==============================] - 0s 862us/step - loss: 0.3097 - mae: 0.3794 - val_loss: 0.3105 - val_mae: 0.3758
# Epoch 14/50
# 516/516 [==============================] - 0s 839us/step - loss: 0.2984 - mae: 0.3769 - val_loss: 0.3049 - val_mae: 0.3745
# Epoch 15/50
# 516/516 [==============================] - 0s 860us/step - loss: 0.2999 - mae: 0.3764 - val_loss: 0.3010 - val_mae: 0.3766
# Epoch 16/50
# 516/516 [==============================] - 0s 845us/step - loss: 0.2909 - mae: 0.3729 - val_loss: 0.3069 - val_mae: 0.3935
# Epoch 17/50
# 516/516 [==============================] - 0s 802us/step - loss: 0.3008 - mae: 0.3720 - val_loss: 0.3049 - val_mae: 0.3772
# Epoch 18/50
# 516/516 [==============================] - 0s 804us/step - loss: 0.2898 - mae: 0.3705 - val_loss: 0.3018 - val_mae: 0.3718
# Epoch 19/50
# 516/516 [==============================] - 0s 804us/step - loss: 0.2852 - mae: 0.3680 - val_loss: 0.3067 - val_mae: 0.3927
# Epoch 20/50
# 516/516 [==============================] - 0s 798us/step - loss: 0.2924 - mae: 0.3703 - val_loss: 0.3012 - val_mae: 0.3841
# Epoch 21/50
# 516/516 [==============================] - 0s 802us/step - loss: 0.2912 - mae: 0.3683 - val_loss: 0.3021 - val_mae: 0.3794
# Epoch 22/50
# 516/516 [==============================] - 0s 837us/step - loss: 0.2817 - mae: 0.3655 - val_loss: 0.2961 - val_mae: 0.3734
# Epoch 23/50
# 516/516 [==============================] - 0s 843us/step - loss: 0.2799 - mae: 0.3642 - val_loss: 0.2916 - val_mae: 0.3639
# Epoch 24/50
# 516/516 [==============================] - 0s 814us/step - loss: 0.2804 - mae: 0.3630 - val_loss: 0.2950 - val_mae: 0.3820
# Epoch 25/50
# 516/516 [==============================] - 0s 835us/step - loss: 0.2797 - mae: 0.3623 - val_loss: 0.2877 - val_mae: 0.3634
# Epoch 26/50
# 516/516 [==============================] - 0s 831us/step - loss: 0.2751 - mae: 0.3602 - val_loss: 0.2945 - val_mae: 0.3650
# Epoch 27/50
# 516/516 [==============================] - 0s 874us/step - loss: 0.2739 - mae: 0.3589 - val_loss: 0.2845 - val_mae: 0.3641
# Epoch 28/50
# 516/516 [==============================] - 0s 833us/step - loss: 0.2803 - mae: 0.3602 - val_loss: 0.2985 - val_mae: 0.3892
# Epoch 29/50
# 516/516 [==============================] - 0s 843us/step - loss: 0.2716 - mae: 0.3569 - val_loss: 0.2843 - val_mae: 0.3594
# Epoch 30/50
# 516/516 [==============================] - 0s 827us/step - loss: 0.2727 - mae: 0.3581 - val_loss: 0.2809 - val_mae: 0.3629
# Epoch 31/50
# 516/516 [==============================] - 0s 812us/step - loss: 0.2690 - mae: 0.3554 - val_loss: 0.2914 - val_mae: 0.3618
# Epoch 32/50
# 516/516 [==============================] - 0s 806us/step - loss: 0.2687 - mae: 0.3554 - val_loss: 0.2821 - val_mae: 0.3600
# Epoch 33/50
# 516/516 [==============================] - 0s 810us/step - loss: 0.2694 - mae: 0.3546 - val_loss: 0.2990 - val_mae: 0.3930
# Epoch 34/50
# 516/516 [==============================] - 0s 796us/step - loss: 0.2699 - mae: 0.3556 - val_loss: 0.2800 - val_mae: 0.3572
# Epoch 35/50
# 516/516 [==============================] - 0s 800us/step - loss: 0.2639 - mae: 0.3525 - val_loss: 0.2818 - val_mae: 0.3684
# Epoch 36/50
# 516/516 [==============================] - 0s 812us/step - loss: 0.2640 - mae: 0.3515 - val_loss: 0.2780 - val_mae: 0.3564
# Epoch 37/50
# 516/516 [==============================] - 0s 855us/step - loss: 0.2674 - mae: 0.3525 - val_loss: 0.2805 - val_mae: 0.3576
# Epoch 38/50
# 516/516 [==============================] - 0s 843us/step - loss: 0.2612 - mae: 0.3499 - val_loss: 0.2848 - val_mae: 0.3547
# Epoch 39/50
# 516/516 [==============================] - 0s 814us/step - loss: 0.2630 - mae: 0.3499 - val_loss: 0.2767 - val_mae: 0.3645
# Epoch 40/50
# 516/516 [==============================] - 0s 818us/step - loss: 0.2608 - mae: 0.3497 - val_loss: 0.2740 - val_mae: 0.3608
# Epoch 41/50
# 516/516 [==============================] - 0s 847us/step - loss: 0.2610 - mae: 0.3488 - val_loss: 0.2966 - val_mae: 0.3619
# Epoch 42/50
# 516/516 [==============================] - 0s 808us/step - loss: 0.2571 - mae: 0.3468 - val_loss: 0.2811 - val_mae: 0.3676
# Epoch 43/50
# 516/516 [==============================] - 0s 816us/step - loss: 0.2591 - mae: 0.3477 - val_loss: 0.2793 - val_mae: 0.3602
# Epoch 44/50
# 516/516 [==============================] - 0s 802us/step - loss: 0.2571 - mae: 0.3462 - val_loss: 0.2810 - val_mae: 0.3727
# Epoch 45/50
# 516/516 [==============================] - 0s 804us/step - loss: 0.2559 - mae: 0.3460 - val_loss: 0.2711 - val_mae: 0.3576
# Epoch 46/50
# 516/516 [==============================] - 0s 814us/step - loss: 0.2551 - mae: 0.3452 - val_loss: 0.2715 - val_mae: 0.3566
# Epoch 47/50
# 516/516 [==============================] - 0s 804us/step - loss: 0.2576 - mae: 0.3459 - val_loss: 0.2762 - val_mae: 0.3489
# Epoch 48/50
# 516/516 [==============================] - 0s 820us/step - loss: 0.2532 - mae: 0.3446 - val_loss: 0.2714 - val_mae: 0.3519
# Epoch 49/50
# 516/516 [==============================] - 0s 812us/step - loss: 0.2522 - mae: 0.3430 - val_loss: 0.2755 - val_mae: 0.3579
# Epoch 50/50
# 516/516 [==============================] - 0s 808us/step - loss: 0.2545 - mae: 0.3432 - val_loss: 0.2762 - val_mae: 0.3552

# %% [markdown]
# ## Visualize Training Performance
# We plot the training and validation loss and MAE to observe the model's performance.

# %%
# Plot training history
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['mae'], label='Training MAE')
plt.plot(history.history['val_mae'], label='Validation MAE')
plt.title('MAE over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Mean Absolute Error')
plt.legend()
plt.show()

# %% [markdown]
# ## Evaluate the Model
# We evaluate the model's performance on the test set and make predictions.

# %%
# Evaluate the model
test_loss, test_mae = model.evaluate(X_test, y_test)
print(f'Test MAE: {test_mae:.3f}')

# %%
# Make predictions
predictions = model.predict(X_test[:10])
print('Predictions:', predictions.flatten())
print('True Values:', y_test[:10])

# %% [markdown]
# ## Compare Predictions vs True Values
# We plot the predicted vs true values for the first few samples.

# %%
# Plot predictions vs true values
plt.figure(figsize=(6, 4))
plt.scatter(range(10), predictions.flatten(), label='Predicted', color='r')
plt.scatter(range(10), y_test[:10], label='True', color='b')
plt.title('Predicted vs True Values')
plt.xlabel('Sample Index')
plt.ylabel('Median House Value')
plt.legend()
plt.show()
